# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from word2number import w2n
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1678754eb76c> in <cell line: 4>()
#       2 import numpy as np
#       3 from sklearn import linear_model
# ----> 4 from word2number import w2n
#
# ModuleNotFoundError: No module named 'word2number'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
d = pd.read_csv("/content/hirings.csv")
d

# %%
d.experience = d.experience.fillna("zero")
d

# %%
d.experience = d.experience.apply(w2n.word_to_num)
d

# %%
import math
median_test_score = math.floor(df['test_score(out of 10)'].mean())
median_test_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c0a15525f764> in <cell line: 2>()
#       1 import math
# ----> 2 median_test_score = math.floor(df['test_score(out of 10)'].mean())
#       3 median_test_score
#
# NameError: name 'df' is not defined

# %%
d['test_score(out of 10)'] = d['test_score(out of 10)'].fillna(median_test_score)
d

# %%
reg = linear_model.LinearRegression()
reg.fit(d[['experience','test_score(out of 10)','interview_score(out of 10)']],d['salary($)'])

# %%
reg.predict([[2,9,6]])

# %%
reg.predict([[12,10,10]])
